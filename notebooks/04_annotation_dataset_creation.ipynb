# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/ADEGuard/vaers_clean_dataset.csv", low_memory=False)

# %%
df_sample = df.sample(800, random_state=42)

# %%
df_sample = df_sample[["SYMPTOM_TEXT"]]

# %%
df_sample.to_csv("/content/drive/MyDrive/ADEGuard/annotation_sample.csv", index=False)
